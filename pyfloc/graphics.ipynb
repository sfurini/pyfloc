# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np
import graphics

# %%
x = [1,10,100,1000]
y = [1,10,100,1000]

# %%
i = [1]
pi = graphics.PointInteractor(x,y,i)
pi.run()
j = pi.get_actives()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
print(j)
print(pi.get_actives())
# Out:
# [1]
# [1]

# %%
f = plt.figure()
ax1 = f.add_subplot(611)
ax1.plot(x,y)
ax2 = f.add_subplot(612)
ax2.plot(x,y)
ax3 = f.add_subplot(613)
ax3.plot(x,y)
ax4 = f.add_subplot(614)
ax4.plot(x,y)
ax5 = f.add_subplot(615)
ax5.plot(x,y)
ax6 = f.add_subplot(616)
ax6.plot(x,y)
i = graphics.AxesScaleInteractor(f)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
from matplotlib.patches import Polygon

theta = np.arange(0, 2*np.pi, 0.1)
r = 1.5
xs = r * np.cos(theta)
ys = r * np.sin(theta)
poly = Polygon(np.column_stack([xs, ys]), animated=True, fill = False)
fig, ax = plt.subplots()
ax.add_patch(poly)
p = graphics.PolygonInteractor(ax, poly)
ax.set_title('Click and drag a point to move it')
ax.set_xlim((-2, 2))
ax.set_ylim((-2, 2))
# Out:
# <div id='dfe38c35-1ac8-4649-9c84-4fb82219d20a'></div>
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-f8e539ffa48f> in <module>()
#       8 fig, ax = plt.subplots()
#       9 ax.add_patch(poly)
# ---> 10 p = graphics.PolygonInteractor(ax, poly)
#      11 ax.set_title('Click and drag a point to move it')
#      12 ax.set_xlim((-2, 2))
#
# ~/Desktop/FLOW/pyfloc/pyfloc/graphics.py in __init__(self, ax, poly)
#     119         self.poly = poly
#     120         x, y = zip(*self.poly.xy)
# --> 121         self.line = Line2D(x, y,
#     122                            marker='o', markerfacecolor='r',
#     123                            animated=True)
#
# NameError: name 'Line2D' is not defined
